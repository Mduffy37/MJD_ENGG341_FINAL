# %%
import pandas as pd

# %% [markdown]
# Importing data set from csv file to Pandas DataFrame

# %%
df = pd.read_csv("../Datasets/pwr_cell_dataset_3k.csv")

# %% [markdown]
# First look into the data set

# %%
df.head()
# Out:
#    Unnamed: 0  Enrichment        FuelT      WaterT     Pitch     FuelR  \
# 0           0   24.430910   664.782614  567.925325  1.642314  0.714294
# 1           1    5.249652   407.024654  569.049024  0.845456  0.249647
# 2           2   82.280322  1363.900826  501.600781  1.379222  0.370878
# 3           3   59.505884   317.487284  443.073845  1.549833  0.536368
# 4           4   19.167943  1460.183440  334.792231  1.906882  0.695364
#
#      WaterD      FuelD      Keff   Std_dev
# 0  0.976810   9.600968  1.507987  0.000323
# 1  0.799552  10.268150 -1.000000 -1.000000
# 2  0.697496  10.205289  1.746744  0.000264
# 3  0.910143  10.211996 -1.000000 -1.000000
# 4  0.877380  10.258945  1.541072  0.000356

# %% [markdown]
# We can see more data, specifying number of the rows we want to see as an argument

# %%
df.head(10)
# Out:
#    Unnamed: 0  Enrichment        FuelT      WaterT     Pitch     FuelR  \
# 0           0   24.430910   664.782614  567.925325  1.642314  0.714294
# 1           1    5.249652   407.024654  569.049024  0.845456  0.249647
# 2           2   82.280322  1363.900826  501.600781  1.379222  0.370878
# 3           3   59.505884   317.487284  443.073845  1.549833  0.536368
# 4           4   19.167943  1460.183440  334.792231  1.906882  0.695364
# 5           5   20.088497  1175.168704  493.911830  0.735232  0.225556
# 6           6   86.675023  1237.672361  597.014917  1.158495  0.221872
# 7           7   76.539829   552.953215  279.406719  1.049147  0.309791
# 8           8   24.866494  1036.397715  293.098113  1.296462  0.555063
# 9           9   77.048680   679.122829  422.327066  1.101318  0.415770
#
#      WaterD      FuelD      Keff   Std_dev
# 0  0.976810   9.600968  1.507987  0.000323
# 1  0.799552  10.268150 -1.000000 -1.000000
# 2  0.697496  10.205289  1.746744  0.000264
# ...

# %% [markdown]
# We can look at the end of the data set

# %%
df.tail()
# Out:
#       Unnamed: 0  Enrichment        FuelT      WaterT     Pitch     FuelR  \
# 2995        2995   28.614898   928.516622  316.549909  1.521848  0.420101
# 2996        2996   12.675710   554.424395  489.148266  1.269696  0.526585
# 2997        2997   55.231024   657.007493  582.701163  0.666839  0.226408
# 2998        2998   59.056211   322.290494  492.242600  1.534810  0.339848
# 2999        2999   56.768920  1476.074673  565.120260  1.389504  0.501724
#
#         WaterD      FuelD      Keff   Std_dev
# 2995  0.785937   9.639033  1.671429  0.000353
# 2996  0.652849   9.690261  1.328700  0.000387
# 2997  0.921731   9.861622  1.641267  0.000269
# 2998  0.963254  10.334469 -1.000000 -1.000000
# 2999  0.777781  10.497132  1.675785  0.000280

# %%
df.tail(10)
# Out:
#       Unnamed: 0  Enrichment        FuelT      WaterT     Pitch     FuelR  \
# 2990        2990   25.863208   459.200047  300.092749  1.566644  0.661519
# 2991        2991   27.589200   511.171525  395.145057  1.961408  0.430278
# 2992        2992   49.488172   602.286781  291.705653  0.758517  0.229832
# 2993        2993   77.364460   587.946109  350.375222  0.879498  0.358961
# 2994        2994    7.935427   482.466843  577.764768  1.388908  0.360118
# 2995        2995   28.614898   928.516622  316.549909  1.521848  0.420101
# 2996        2996   12.675710   554.424395  489.148266  1.269696  0.526585
# 2997        2997   55.231024   657.007493  582.701163  0.666839  0.226408
# 2998        2998   59.056211   322.290494  492.242600  1.534810  0.339848
# 2999        2999   56.768920  1476.074673  565.120260  1.389504  0.501724
#
#         WaterD      FuelD      Keff   Std_dev
# 2990  0.654790   9.848495  1.513110  0.000323
# 2991  0.990782  10.003415  1.746366  0.000331
# ...

# %% [markdown]
# General info about the DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  3000 non-null   int64
#  1   Enrichment  3000 non-null   float64
#  2   FuelT       3000 non-null   float64
#  3   WaterT      3000 non-null   float64
#  4   Pitch       3000 non-null   float64
#  5   FuelR       3000 non-null   float64
#  6   WaterD      3000 non-null   float64
#  7   FuelD       3000 non-null   float64
#  8   Keff        3000 non-null   float64
#  9   Std_dev     3000 non-null   float64
# dtypes: float64(9), int64(1)
# memory usage: 234.5 KB

# %% [markdown]
# First analysis of the dataset

# %%
df.describe()
# Out:
#         Unnamed: 0   Enrichment        FuelT       WaterT        Pitch  \
# count  3000.000000  3000.000000  3000.000000  3000.000000  3000.000000
# mean   1499.500000    45.410641  1048.941400   444.582348     1.293330
# std     866.169729    26.024975   429.890523    97.730529     0.402200
# min       0.000000     0.701673   274.004301   274.110729     0.600455
# 25%     749.750000    22.491088   682.748116   359.609354     0.953251
# 50%    1499.500000    45.401880  1056.856655   445.466237     1.277342
# 75%    2249.250000    67.814310  1413.092728   529.759216     1.640349
# max    2999.000000    89.920130  1799.958886   609.898521     1.999883
#
#              FuelR       WaterD        FuelD         Keff      Std_dev
# count  3000.000000  3000.000000  3000.000000  3000.000000  3000.000000
# mean      0.382623     0.804298     9.999803     1.375088    -0.098724
# std       0.155333     0.112963     0.291719     0.803203     0.298803
# ...

# %% [markdown]
# Excluding negative Keff values from the data set

# %%
df = df.drop(df[df.Keff < 0].index).reset_index(drop=True)

# %% [markdown]
# Excluding unnecessary columns from the data set

# %%
df = df.drop("Unnamed: 0", axis=1)

# %%
df.head()
# Out:
#    Enrichment        FuelT      WaterT     Pitch     FuelR    WaterD  \
# 0   24.430910   664.782614  567.925325  1.642314  0.714294  0.976810
# 1   82.280322  1363.900826  501.600781  1.379222  0.370878  0.697496
# 2   19.167943  1460.183440  334.792231  1.906882  0.695364  0.877380
# 3   20.088497  1175.168704  493.911830  0.735232  0.225556  0.830257
# 4   86.675023  1237.672361  597.014917  1.158495  0.221872  0.905299
#
#        FuelD      Keff   Std_dev
# 0   9.600968  1.507987  0.000323
# 1  10.205289  1.746744  0.000264
# 2  10.258945  1.541072  0.000356
# 3  10.246023  1.515049  0.000410
# 4  10.250478  1.802780  0.000263

# %%
df.describe()
# Out:
#         Enrichment        FuelT       WaterT        Pitch        FuelR  \
# count  2703.000000  2703.000000  2703.000000  2703.000000  2703.000000
# mean     45.368827  1121.681313   439.081266     1.290129     0.382388
# std      25.932962   388.610045    97.794341     0.403002     0.155326
# min       0.701673   288.603154   274.110729     0.600455     0.200001
# 25%      22.521960   791.021642   354.243819     0.949844     0.254298
# 50%      45.490206  1131.192864   438.200578     1.272138     0.337028
# 75%      67.507247  1449.502605   523.556560     1.636711     0.476663
# max      89.920130  1799.958886   609.813585     1.999883     0.907305
#
#             WaterD        FuelD         Keff      Std_dev
# count  2703.000000  2703.000000  2703.000000  2703.000000
# mean      0.804533     9.997916     1.636058     0.000307
# std       0.112651     0.291059     0.166917     0.000056
# min       0.610116     9.500037     0.626834     0.000170
# ...

# %%
df.tail()
# Out:
#       Enrichment        FuelT      WaterT     Pitch     FuelR    WaterD  \
# 2698   77.364460   587.946109  350.375222  0.879498  0.358961  0.809106
# 2699   28.614898   928.516622  316.549909  1.521848  0.420101  0.785937
# 2700   12.675710   554.424395  489.148266  1.269696  0.526585  0.652849
# 2701   55.231024   657.007493  582.701163  0.666839  0.226408  0.921731
# 2702   56.768920  1476.074673  565.120260  1.389504  0.501724  0.777781
#
#           FuelD      Keff   Std_dev
# 2698  10.340870  1.832681  0.000221
# 2699   9.639033  1.671429  0.000353
# 2700   9.690261  1.328700  0.000387
# 2701   9.861622  1.641267  0.000269
# 2702  10.497132  1.675785  0.000280

# %% [markdown]
# Exproting clean data set to the csv file

# %%
df.to_csv("pwr_cell_dataset_clean_3k.csv", index=False)

# %% [markdown]
# Plotting some of the data

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df.Enrichment, df.Keff)

# %%
plt.scatter(df.Pitch, df.Keff)

# %%
plt.scatter(df.FuelT, df.Keff)

# %%
plt.scatter(df.FuelR, df.Keff)

# %% [markdown]
# Calculating correlation table

# %%
df.corr()
# Out:
#             Enrichment     FuelT    WaterT     Pitch     FuelR    WaterD  \
# Enrichment    1.000000  0.003845  0.004064 -0.021925  0.001459  0.022546
# FuelT         0.003845  1.000000  0.124226  0.022076 -0.001274 -0.020910
# WaterT        0.004064  0.124226  1.000000 -0.005905  0.022403 -0.010221
# Pitch        -0.021925  0.022076 -0.005905  1.000000  0.630378  0.006884
# FuelR         0.001459 -0.001274  0.022403  0.630378  1.000000 -0.014157
# WaterD        0.022546 -0.020910 -0.010221  0.006884 -0.014157  1.000000
# FuelD        -0.000634  0.009386  0.008578  0.012586 -0.007912  0.017190
# Keff          0.765452 -0.055464 -0.030738  0.161409 -0.041508  0.076207
# Std_dev      -0.864527  0.006754  0.015325  0.017904 -0.057177  0.008655
#
#                FuelD      Keff   Std_dev
# Enrichment -0.000634  0.765452 -0.864527
# FuelT       0.009386 -0.055464  0.006754
# WaterT      0.008578 -0.030738  0.015325
# Pitch       0.012586  0.161409  0.017904
# ...
